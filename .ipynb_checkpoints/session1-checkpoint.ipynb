# %%
import pandas as pd, warnings; warnings.filterwarnings('ignore')

dfs = {f:pd.read_csv(f) for f in ['customers.csv', 'products.csv', 'sales_transactions.csv']}
# ดึงข้อมูล 3 ตาราง
[ display(d.head()) for d in dfs.values() ]
# เป็นค่าว่างรอข้อมูลมาใส่
report = ""


# ....c = ... check
# ....m = ....mask
for name, df in dfs.items():
    # col = column \\ typ = types
    report += f"\n### File: {name} \n Data Types:\n" + "\n".join([f"-{col}:{typ}])"for col, typ in df.dtypes.items()]) + "\n\nInconsistencies Or Anomalies:\n"
    
    # find column that has "date" in it
    dc = [col for col in df.columns if 'date' in col.lower()]
    
    # concat คือ ฟังก์ชันสำหรับ "เชื่อม" หรือ "รวม" อ็อบเจ็กต์ Pandas (DataFrame หรือ Series) ตั้งแต่ 2 ชุดขึ้นไปเข้าด้วยกันตามแกนที่กำหนด (Axis)
    ############################################################################# Date Time Checking #####################################################################################
    
    dm = pd.concat([pd.to_datetime(df [col], errors='coerce').pipe(lambda s: s.isna() | ~s.dt.year.between(2010, 2025)) for col in dc ], axis = 1).any(axis = 1) if dc else [0] * len (df)

    # find column that has 'quantity', 'price', 'cost' in it
    nc = [col for col in ['quantity', 'price', 'cost'] if col in df.columns]

    ############################################################################ Negative Number Checking #####################################################################################
    nm = pd.concat([pd.to_numeric(df[col].astype(str).str.replace('$','', regex = False), errors = 'coerce') < 0 for col in nc], axis = 1).any(axis = 1) if nc else [0] * len(df)

    # find column that has ID in it if null = 0
    idm = (~df.customer_id.isin(dfs['customers.csv'].customer_id) | ~df.product_id.isin(dfs['products.csv'].product_id)) if name == 'sales_transactions.csv' else [0] * len(df)
    
    ############################################################################ Unexpected Checking #####################################################################################
    um = ( ~df.gender.isin(['M','F']) | ~df.membership_status.str.title().isin(['Basic','Silver','Gold']) | ~df.preferred_category.isin(['Macaron','Bread','Pastries','Tarte', 'To Be Determined', 'TBD']) | ~df.churned.isin(['TRUE', 'FALSE']) if name == 'customers.csv' else (~df.category.isin(['Pastries','Bread','Tarte','Viennoiserie']) | ~df.seasonal.isin(['TRUE','FALSE']) | ~df.active.isin(['TRUE','FALSE'])) if name == 'products.csv' else (~df.payment_method.isin(['Credit Card','Mobile Pay','Cash']) | ~df.channel.isin(['Online','In-store'])) if name == 'sales_transactions.csv' else [0]*len(df))
# Out:
#    customer_id first_name  last_name   age gender  postal_code  \
# 0          101        Léa       King  60.0      M        69003
# 1          102      Chloé      Smith  31.0      F        69006
# 2          103     Harper   Robinson  38.0      M        69006
# 3          104      Ethan  Rodriguez  54.0      F        69001
# 4          105        Ava      Allen  50.0      F        69006
#
#                         email phone_number membership_status  \
# 0             Lking@orange.fr  33765451688             Basic
# 1          CSMITH@HOTMAIL.COM          NaN              Gold
# 2           harperr@yahoo.com  33148254771             Basic
# 3  ETHAN_RODRIGUEZ@YANDEX.COM  33118046627             Basic
# 4       Ava.allen@hotmail.com  33267246001            Silver
#
#              join_date last_purchase_date  total_spending  \
# 0            14/5/2095           8/1/1960          205.92
# 1            15/1/2074          17/9/1902          744.21
# 2            1/25/2022                NaN          929.52
# 3  2033-03-23 00:00:00          7/17/2023          731.21
# 4            16/3/2000          5/18/2023          629.48
#
#    average_order_value  frequency preferred_category churned
# 0              1124.64         26            Macaron   False
# 1              4403.42         24              Bread   False
# 2                42.25         22           Pastries   False
# 3                33.24         22            Unknown   False
# 4                16.57         38              Bread    True
#    product_id                     product_name category  \
# 0         1.0                Tarte Tropézienne    Tarte
# 1         2.0                 tarte bourdaloue    Tarte
# 2         3.0                    tarte flambée      NaN
# 3         4.0                   Tarte Normande    Tarte
# 4         5.0  Tarte au Citron Vert et Basilic    Tarte
#
#                                          ingredients   price cost seasonal  \
# 0  Brioche dough, pastry cream, orange blossom wa...  $6.50   $3     False
# 1  Sweet pastry crust, almond cream, poached pear...  $7.00   $2      True
# 2   Thin dough, crème fraîche, onions, bacon lardons  $8.50   $2      True
# 3  Sweet pastry crust, apples, Calvados custard, ...  $6.50   NaN    False
# 4  Tart shell, lime curd, fresh basil, meringue k...  $7.50   $2        No
#
#   active      introduced_date
# 0   True  2018-03-25 00:00:00
# 1    Yes  2015-10-01 00:00:00
# 2   True                  NaN
# 3   True  2033-12-23 00:00:00
# 4   True                  NaN
#    transaction_id  customer_id        date  product_id  quantity  price  \
# 0            8613          683  2023-11-30           6         1   2.92
# 1            1144          166  2023-11-30          15         1   3.67
# 2            9130          263  2023-11-30          21         1   6.37
# 3            6649          576  2023-11-30          15         1   3.16
# 4              88          276  2023-11-30          15         1   4.54
#
#   payment_method   channel  store_id  promotion_id  discount_amount
# 0    Credit Card    Online       NaN           NaN             0.00
# 1    Credit Card    Online       NaN           2.0             0.37
# 2     Mobile Pay  In-store       5.0           NaN             0.00
# 3     Mobile Pay  In-store       2.0           NaN             0.00
# 4    Credit Card    Online       NaN           8.0             0.45
